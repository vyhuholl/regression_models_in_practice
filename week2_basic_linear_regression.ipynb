# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
data = pd.read_csv('gapminder.csv', low_memory=False)

# %%
data.head()
# Out:
#        country   incomeperperson alcconsumption armedforcesrate  \
# 0  Afghanistan                              .03        .5696534
# 1      Albania  1914.99655094922           7.29       1.0247361
# 2      Algeria  2231.99333515006            .69        2.306817
# 3      Andorra  21943.3398976022          10.17
# 4       Angola  1381.00426770244           5.57       1.4613288
#
#   breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# 0                 26.8          75944000  25.6000003814697
# 1                 57.4  223747333.333333  42.0999984741211
# 2                 23.5  2932108666.66667  31.7000007629394      .1
# 3
# 4                 23.1         248358000  69.4000015258789       2
#
#     internetuserate lifeexpectancy     oilperperson polityscore  \
# 0  3.65412162280064         48.673                            0
# 1  44.9899469578783         76.918                            9
# 2  12.5000733055148         73.131  .42009452521537           2
# ...

# %%
#converting to numeric
data['internetuserate'] = pd.to_numeric(data['internetuserate'], errors='coerce')
data['urbanrate'] = pd.to_numeric(data['urbanrate'], errors='coerce')

# %%
#deleting rows containing missing data on explanatory or response variables
data = data.dropna(subset=['internetuserate', 'urbanrate'])

# %%
data['urbanrate'] = data['urbanrate'] - data['urbanrate'].mean()
#subtracting the mean from explanatory variable
data['urbanrate'].mean() #see? the mean is close to 0!
# Out:
# 1.3201136090700809e-14

# %%
X = np.asarray(data['urbanrate'])
y = np.asarray(data['internetuserate'])

regr = sm.OLS(y, X)
result = regr.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     31.50
# Date:                Fri, 29 Mar 2019   Prob (F-statistic):           7.02e-08
# Time:                        20:02:07   Log-Likelihood:                -978.61
# No. Observations:                 190   AIC:                             1959.
# Df Residuals:                     189   BIC:                             1962.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7202      0.128      5.613      0.000       0.467       0.973
# ...
