# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
data = pd.read_csv('ool_pds.csv', low_memory=False)

# %%
data.head()
# Out:
#    CASEID  W1_CASEID W2_CASEID2                          W1_TM_START  \
# 0       1          2        820  BLANKED FOR CONFIDENTIALITY - ICPSR
# 1       2          3             BLANKED FOR CONFIDENTIALITY - ICPSR
# 2       3          4       1198  BLANKED FOR CONFIDENTIALITY - ICPSR
# 3       4          5        240  BLANKED FOR CONFIDENTIALITY - ICPSR
# 4       5          6             BLANKED FOR CONFIDENTIALITY - ICPSR
#
#                           W1_TM_FINISH  W1_WEIGHT1  W1_WEIGHT2  W1_WEIGHT3  \
# 0  BLANKED FOR CONFIDENTIALITY - ICPSR      4.8559      2.4181      2.3315
# 1  BLANKED FOR CONFIDENTIALITY - ICPSR      0.0415      0.2091      0.1954
# 2  BLANKED FOR CONFIDENTIALITY - ICPSR      0.7628      3.8416      3.5907
# 3  BLANKED FOR CONFIDENTIALITY - ICPSR      0.0089      0.0448      0.0418
# 4  BLANKED FOR CONFIDENTIALITY - ICPSR      1.9532      0.9727      0.9378
#
#                            W2_TM_START                         W2_TM_FINISH  \
# ...

# %%
#converting to numeric
data['PPINCIMP'] = pd.to_numeric(data['PPINCIMP'], errors='coerce')
data['W2_QE1'] = pd.to_numeric(data['W2_QE1'], errors='coerce')
#replacing category labels with 0 and 1 for simplicity
data['W2_QE1'] = data['W2_QE1'].replace(to_replace={1: 0, 2: 1})
#excluding missing and incorrect values
data = data.dropna(subset=['PPINCIMP', 'W2_QE1'])
data = data.query('W2_QE1 in [0, 1]')
#subtracting the mean from explanatory variable
data['PPINCIMP'] = data['PPINCIMP'] - data['PPINCIMP'].mean()
data.shape
# Out:
# (1110, 436)

# %%
logr = smf.logit(formula='W2_QE1~PPINCIMP', data=data)
result = logr.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.510090
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 W2_QE1   No. Observations:                 1110
# Model:                          Logit   Df Residuals:                     1108
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 30 Mar 2019   Pseudo R-squ.:               0.0002792
# Time:                        15:50:11   Log-Likelihood:                -566.20
# converged:                       True   LL-Null:                       -566.36
#                                         LLR p-value:                    0.5739
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
